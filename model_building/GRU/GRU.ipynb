# %%
import pandas as pd
import numpy as np
from collections import Counter
import logging
import string
import re
import os
from tqdm.notebook import tqdm
from random import randint, shuffle

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    ConfusionMatrixDisplay,
    accuracy_score,
    f1_score
)

import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

device = 'cuda' if torch.cuda.is_available() else 'cpu'
sns.set_theme()
logging.basicConfig(filename='training_log.log',
                    format='%(asctime)s - %(message)s', 
                    level=logging.INFO,
                    filemode='w')
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='training_log.log', mode='a')
formatter = logging.Formatter('%(asctime)s: %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)


class GRU(nn.Module):
    def __init__(self, vocab_size, d_model, num_layers, num_classes):
        super(GRU, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.gru = nn.GRU(d_model, d_model, num_layers, batch_first=True)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        x = self.embedding(x)
        _, x = self.gru(x)
        x = x[-1]  
        x = self.fc(x)
        return x

class Tokenizer:
    def __init__(self, text_list, max_vocab_size=20000, n=3):
        self.max_vocab_size = max_vocab_size
        self.oov_token = "<OOV>"
        self.n = n
        self.build_vocab(text_list)

    def build_vocab(self, text_list):
        all_text = " ".join(self.preprocess(text) for text in text_list)
        ngrams = [self.ngramify(word) for word in all_text.split()]
        ngrams_flat = [ngram for word_ngrams in ngrams for ngram in word_ngrams] 
        ngram_count = Counter(ngrams_flat)
        vocab = [self.oov_token] + sorted(ngram_count, key=ngram_count.get, reverse=True)
        vocab = vocab[:self.max_vocab_size]
        self.word_to_id = {word: i for i, word in enumerate(vocab)}
        self.id_to_word = {i: word for word, i in self.word_to_id.items()}
        self.vocab_size = len(self.word_to_id)

    def preprocess(self, text):
        return text.lower()

    def ngramify(self, word):
        return [word[i:i + self.n] for i in range(len(word) - self.n + 1)]

    def encode(self, text):
        text = self.preprocess(text)
        words = text.split()
        ids = []
        for word in words:
            ngrams = self.ngramify(word)
            word_ids = [self.word_to_id.get(ngram, self.word_to_id[self.oov_token]) for ngram in ngrams]
            ids.extend(word_ids)
        return ids

    def decode(self, ids):
        ngrams = [self.id_to_word.get(id, self.oov_token) for id in ids]
        return "".join(ngrams)

    def __len__(self):
        return self.vocab_size


device = 'cuda' if torch.cuda.is_available() else 'cpu'


def pad_sequences(sequences, max_length):
    padded_sequences = []
    for seq in sequences:
        if len(seq) > max_length:
            seq = seq[:max_length]
        padded_seq = seq + [0] * (max_length - len(seq))
        padded_sequences.append(padded_seq)
    return padded_sequences

class DS(Dataset):
    def __init__(self, data_path, tokenizer, max_token_length=512):
        super().__init__()
        self.max_token_length = max_token_length

        self.labels = [
            'hate',
            'privacy',
            'sexual',
            'impersonation',
            'illegal',
            'advertisement',
            'ai',
            'neutral'
        ]

        self.data = pd.read_csv(data_path)
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.loc[idx, :]


        comment = row['body']
        comment = comment.split()

        if len(comment) > self.max_token_length:
            comment = comment[:self.max_token_length]
        comment = ' '.join(comment)
        comment = comment.replace("\\", "")

        emotion = row['label']
        emotion = self.labels.index(emotion)

        return f"{comment}", emotion

    def choose(self):
        return self[randint(0, len(self)-1)]

    def get_tokenizer_size(self):
        return len(self.tokenizer)

    def decode(self, input_id):
        return self.tokenizer.decode(input_id)

    def collate_fn(self, data):
        comments, emotions = zip(*data)
        comments = [self.tokenizer.encode(comment) for comment in comments]
        comments = pad_sequences(comments, self.max_token_length)
        comments = torch.tensor(comments, dtype=torch.long, device=device)
        emotions = torch.tensor(emotions).long().to(device)
        return comments, emotions

# %%
val_path = 'https://drive.google.com/uc?export=download&id=1ZMJI7DyKMLHpHp-HBUO64kWbP6A-qj9k'
train_path = 'https://drive.google.com/uc?export=download&id=1ZTfYOXeZLW57mLR7IegIFovi7FW1chS6'
train_df_orig = pd.read_csv(train_path)
val_df_orig = pd.read_csv(val_path)

train_df = train_df_orig.copy()
val_df = val_df_orig.copy()
print(f'Size of training data: {len(train_df)}')
print(f'Size of validation data: {len(val_df)}')

tokenizer = Tokenizer(train_df["body"].tolist())
batch_size = 16

train_ds = DS(train_path, tokenizer)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True, collate_fn=train_ds.collate_fn)
val_ds = DS(val_path, tokenizer)
val_dl = DataLoader(val_ds, batch_size=batch_size, collate_fn=val_ds.collate_fn)
# Out:
# Size of training data: 44188
# Size of validation data: 4910

# %%
model = GRU(vocab_size=train_ds.get_tokenizer_size(), d_model=128, num_layers=4, num_classes=len(train_ds.labels)).to(device)

# %%
def compute_metrics(targets, preds):
    targets = targets.cpu().detach()
    preds = preds.cpu().detach()
    acc = accuracy_score(targets, preds)
    f1 = f1_score(targets, preds, average='weighted')
    return {'acc': acc, 'f1': f1, 'preds': preds, 'targets':targets}

def focal_loss(gamma=2):
    def compute_loss(preds, targets):
        ce_loss = F.cross_entropy(preds, targets, reduction='none')
        pt = torch.exp(-ce_loss) 
        return ((1-pt)**gamma * ce_loss).mean()
    return compute_loss

def train(data, model, optimizer, label_loss_fn, ft_lambda=1e-4):
    model.train()
    comments, labels = data
    label_outputs = model(comments)
    label_loss = label_loss_fn(label_outputs, labels)
    loss = label_loss
    model.zero_grad()
    loss.backward()
    optimizer.step()

    label_preds = label_outputs.argmax(-1)
    label_metrics = compute_metrics(labels, label_preds)
    return loss, label_metrics

@torch.no_grad()
def validate(data, model, label_loss_fnn):
    model.eval()
    comments, labels = data
    label_outputs = model(comments)
    label_loss = label_loss_fnn(label_outputs, labels)
    loss = label_loss

    label_preds = label_outputs.argmax(-1)
    label_metrics = compute_metrics(labels, label_preds)
    return loss, label_metrics

n_epoch = 100
loss_fn = focal_loss()
optimizer = optim.AdamW(model.parameters(), lr=2e-5, weight_decay=0.01)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)

# %%
mem = {
    'train_loss': [],
    'train_acc': [],
    'train_f1': [],
    'val_loss': [],
    'val_acc': [],
    'val_f1': []
}

cur_best_f1 = 0

for epoch in tqdm(range(n_epoch), desc='Training'):

    n_batch = len(train_dl)
    train_losses = []
    train_accs = []
    train_f1s = []

    for i, data in enumerate(train_dl):
        train_loss, train_metrics = train(data, model, optimizer, loss_fn, loss_fn)
        pos = epoch + ((i+1)/n_batch)
        train_losses.append(train_loss.cpu().detach())
        train_accs.append(train_metrics['acc'])
        train_f1s.append(train_metrics['f1'])
        log = f"epoch: {pos:.3f}\ttrain loss: {train_loss:.3f}\ttrain_acc: {train_metrics['acc']:.3f}\ttrain_f1: {train_metrics['f1']:.3f}"
        print('\r', log, end='')
    
    mem['train_loss'].append(np.mean(train_losses))
    mem['train_acc'].append(np.mean(train_accs))
    mem['train_f1'].append(np.mean(train_f1s))

    n_batch = len(val_dl)
    val_losses = []
    val_accs = []
    val_f1s = []

    for i, data in enumerate(val_dl):
        val_loss, val_metrics = validate(data, model, loss_fn)
        pos = epoch + ((i+1)/n_batch)
        val_losses.append(val_loss.cpu().detach())
        val_accs.append(val_metrics['acc'])
        val_f1s.append(val_metrics['f1'])
        log = f"epoch: {pos:.3f}\tval loss: {val_loss:.3f}\tval_acc: {val_metrics['acc']:.3f}\tval_f1: {val_metrics['f1']:.3f}"
        print('\r', log, end='')
    
    print('\r', end='')
    mem['val_loss'].append(np.mean(val_losses))
    mem['val_acc'].append(np.mean(val_accs))
    mem['val_f1'].append(np.mean(val_f1s))

    log = f"epoch: {epoch+1}\ntrain loss: {mem['train_loss'][-1]:.3f}\ttrain_acc: {mem['train_acc'][-1]:.3f}\ttrain_f1: {mem['train_f1'][-1]:.3f}"
    log = log + f"\nval loss:   {mem['val_loss'][-1]:.3f}\tval_acc:   {mem['val_acc'][-1]:.3f}\tval_f1:   {mem['val_f1'][-1]:.3f}\n"
    logger.info(log)
    print(log)
    scheduler.step()    

    if mem['val_f1'][-1] > cur_best_f1:
        torch.save(model.state_dict(), f"gru_state.pth")
        cur_best_f1 = mem['val_f1'][-1]
# Out:
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# epoch: 1
# train loss: 0.642	train_acc: 0.437	train_f1: 0.277
# val loss:   0.602	val_acc:   0.406	val_f1:   0.254
#
# epoch: 2
# train loss: 0.600	train_acc: 0.440	train_f1: 0.284
# val loss:   0.600	val_acc:   0.443	val_f1:   0.282
#
# epoch: 3
# train loss: 0.563	train_acc: 0.567	train_f1: 0.471
# val loss:   0.444	val_acc:   0.714	val_f1:   0.661
#
# epoch: 4
# train loss: 0.391	train_acc: 0.749	train_f1: 0.694
# val loss:   0.357	val_acc:   0.754	val_f1:   0.698
#
# epoch: 5
# train loss: 0.337	train_acc: 0.771	train_f1: 0.726
# val loss:   0.316	val_acc:   0.789	val_f1:   0.757
#
# epoch: 6
# train loss: 0.305	train_acc: 0.807	train_f1: 0.790
# val loss:   0.290	val_acc:   0.823	val_f1:   0.806
#
# epoch: 7
# train loss: 0.280	train_acc: 0.827	train_f1: 0.813
# val loss:   0.270	val_acc:   0.837	val_f1:   0.823
#
# epoch: 8
# train loss: 0.262	train_acc: 0.840	train_f1: 0.826
# val loss:   0.256	val_acc:   0.847	val_f1:   0.832
#
# epoch: 9
# train loss: 0.248	train_acc: 0.851	train_f1: 0.837
# val loss:   0.249	val_acc:   0.848	val_f1:   0.830
#
# epoch: 10
# train loss: 0.238	train_acc: 0.858	train_f1: 0.844
# val loss:   0.236	val_acc:   0.861	val_f1:   0.847
#
# epoch: 11
# train loss: 0.230	train_acc: 0.862	train_f1: 0.848
# val loss:   0.231	val_acc:   0.863	val_f1:   0.848
#
# epoch: 12
# train loss: 0.224	train_acc: 0.867	train_f1: 0.853
# val loss:   0.231	val_acc:   0.865	val_f1:   0.851
#
# epoch: 13
# train loss: 0.219	train_acc: 0.869	train_f1: 0.856
# val loss:   0.223	val_acc:   0.865	val_f1:   0.849
#
# epoch: 14
# train loss: 0.214	train_acc: 0.872	train_f1: 0.858
# val loss:   0.221	val_acc:   0.865	val_f1:   0.852
#
# epoch: 15
# train loss: 0.210	train_acc: 0.874	train_f1: 0.861
# val loss:   0.220	val_acc:   0.870	val_f1:   0.856
#
# epoch: 16
# train loss: 0.207	train_acc: 0.876	train_f1: 0.862
# val loss:   0.217	val_acc:   0.866	val_f1:   0.854
#
# epoch: 17
# train loss: 0.204	train_acc: 0.878	train_f1: 0.864
# val loss:   0.213	val_acc:   0.873	val_f1:   0.858
#
# epoch: 18
# train loss: 0.200	train_acc: 0.879	train_f1: 0.865
# val loss:   0.216	val_acc:   0.872	val_f1:   0.856
#
# epoch: 19
# train loss: 0.198	train_acc: 0.880	train_f1: 0.866
# val loss:   0.213	val_acc:   0.870	val_f1:   0.855
#
# epoch: 20
# train loss: 0.195	train_acc: 0.881	train_f1: 0.867
# val loss:   0.215	val_acc:   0.868	val_f1:   0.856
#
# epoch: 21
# train loss: 0.192	train_acc: 0.883	train_f1: 0.869
# val loss:   0.212	val_acc:   0.871	val_f1:   0.858
#
# epoch: 22
# train loss: 0.190	train_acc: 0.883	train_f1: 0.870
# val loss:   0.210	val_acc:   0.873	val_f1:   0.859
#
# epoch: 23
# train loss: 0.188	train_acc: 0.885	train_f1: 0.872
# val loss:   0.208	val_acc:   0.875	val_f1:   0.860
#
# epoch: 24
# train loss: 0.186	train_acc: 0.885	train_f1: 0.872
# val loss:   0.208	val_acc:   0.874	val_f1:   0.860
#
# epoch: 25
# train loss: 0.184	train_acc: 0.886	train_f1: 0.872
# val loss:   0.208	val_acc:   0.875	val_f1:   0.861
#
# epoch: 26
# train loss: 0.182	train_acc: 0.887	train_f1: 0.873
# val loss:   0.210	val_acc:   0.874	val_f1:   0.860
#
# epoch: 27
# train loss: 0.180	train_acc: 0.887	train_f1: 0.874
# val loss:   0.210	val_acc:   0.876	val_f1:   0.862
#
# epoch: 28
# train loss: 0.179	train_acc: 0.888	train_f1: 0.875
# val loss:   0.214	val_acc:   0.874	val_f1:   0.858
#
# epoch: 29
# train loss: 0.177	train_acc: 0.889	train_f1: 0.875
# val loss:   0.210	val_acc:   0.876	val_f1:   0.862
#
# epoch: 30
# train loss: 0.176	train_acc: 0.889	train_f1: 0.875
# val loss:   0.209	val_acc:   0.875	val_f1:   0.861
#
# epoch: 31
# train loss: 0.175	train_acc: 0.890	train_f1: 0.877
# val loss:   0.209	val_acc:   0.876	val_f1:   0.861
#
# epoch: 32
# train loss: 0.174	train_acc: 0.890	train_f1: 0.877
# val loss:   0.210	val_acc:   0.876	val_f1:   0.862
#
# epoch: 33
# train loss: 0.172	train_acc: 0.891	train_f1: 0.878
# val loss:   0.210	val_acc:   0.876	val_f1:   0.862
#
# epoch: 34
# train loss: 0.171	train_acc: 0.891	train_f1: 0.878
# val loss:   0.209	val_acc:   0.876	val_f1:   0.862
#
# epoch: 35
# train loss: 0.171	train_acc: 0.892	train_f1: 0.878
# val loss:   0.210	val_acc:   0.876	val_f1:   0.862
#
# epoch: 36
# train loss: 0.170	train_acc: 0.892	train_f1: 0.879
# val loss:   0.210	val_acc:   0.874	val_f1:   0.861
#
# epoch: 37
# train loss: 0.169	train_acc: 0.893	train_f1: 0.879
# val loss:   0.210	val_acc:   0.876	val_f1:   0.862
#
# epoch: 38
# train loss: 0.168	train_acc: 0.893	train_f1: 0.879
# val loss:   0.212	val_acc:   0.878	val_f1:   0.864
#
# epoch: 39
# train loss: 0.167	train_acc: 0.893	train_f1: 0.880
# val loss:   0.212	val_acc:   0.877	val_f1:   0.862
#
# epoch: 40
# train loss: 0.166	train_acc: 0.894	train_f1: 0.880
# val loss:   0.212	val_acc:   0.875	val_f1:   0.862
#
# epoch: 41
# train loss: 0.165	train_acc: 0.894	train_f1: 0.881
# val loss:   0.212	val_acc:   0.876	val_f1:   0.862
#
# epoch: 42
# train loss: 0.164	train_acc: 0.894	train_f1: 0.881
# val loss:   0.212	val_acc:   0.877	val_f1:   0.863
#
# epoch: 43
# train loss: 0.164	train_acc: 0.895	train_f1: 0.882
# val loss:   0.214	val_acc:   0.877	val_f1:   0.863
#
# epoch: 44
# train loss: 0.163	train_acc: 0.895	train_f1: 0.881
# val loss:   0.214	val_acc:   0.877	val_f1:   0.863
#
# epoch: 45
# train loss: 0.163	train_acc: 0.895	train_f1: 0.882
# val loss:   0.213	val_acc:   0.877	val_f1:   0.863
#
# epoch: 46
# train loss: 0.162	train_acc: 0.896	train_f1: 0.882
# val loss:   0.213	val_acc:   0.877	val_f1:   0.863
#
# epoch: 47
# train loss: 0.161	train_acc: 0.896	train_f1: 0.883
# val loss:   0.214	val_acc:   0.877	val_f1:   0.863
#
# epoch: 48
# train loss: 0.161	train_acc: 0.896	train_f1: 0.882
# val loss:   0.214	val_acc:   0.876	val_f1:   0.862
#
# epoch: 49
# train loss: 0.160	train_acc: 0.897	train_f1: 0.883
# val loss:   0.214	val_acc:   0.877	val_f1:   0.863
#
# epoch: 50
# train loss: 0.160	train_acc: 0.897	train_f1: 0.883
# val loss:   0.215	val_acc:   0.878	val_f1:   0.864
#
# epoch: 51
# train loss: 0.159	train_acc: 0.897	train_f1: 0.883
# val loss:   0.216	val_acc:   0.878	val_f1:   0.864
#
# epoch: 52
# train loss: 0.159	train_acc: 0.897	train_f1: 0.883
# val loss:   0.216	val_acc:   0.877	val_f1:   0.863
#
# epoch: 53
# train loss: 0.159	train_acc: 0.897	train_f1: 0.884
# val loss:   0.217	val_acc:   0.877	val_f1:   0.863
#
# epoch: 54
# train loss: 0.158	train_acc: 0.897	train_f1: 0.884
# val loss:   0.218	val_acc:   0.878	val_f1:   0.864
#
# epoch: 55
# train loss: 0.158	train_acc: 0.897	train_f1: 0.884
# val loss:   0.219	val_acc:   0.878	val_f1:   0.864
#
# epoch: 56
# train loss: 0.158	train_acc: 0.897	train_f1: 0.884
# val loss:   0.217	val_acc:   0.877	val_f1:   0.864
#
# epoch: 57
# train loss: 0.157	train_acc: 0.898	train_f1: 0.885
# val loss:   0.218	val_acc:   0.876	val_f1:   0.863
#
# epoch: 58
# train loss: 0.157	train_acc: 0.898	train_f1: 0.884
# val loss:   0.218	val_acc:   0.878	val_f1:   0.864
#
# epoch: 59
# train loss: 0.156	train_acc: 0.898	train_f1: 0.884
# val loss:   0.218	val_acc:   0.877	val_f1:   0.863
#
# epoch: 60
# train loss: 0.156	train_acc: 0.898	train_f1: 0.884
# val loss:   0.218	val_acc:   0.876	val_f1:   0.863
#
# epoch: 61
# train loss: 0.156	train_acc: 0.898	train_f1: 0.884
# val loss:   0.218	val_acc:   0.878	val_f1:   0.864
#
# epoch: 62
# train loss: 0.156	train_acc: 0.898	train_f1: 0.885
# val loss:   0.219	val_acc:   0.877	val_f1:   0.863
#
# epoch: 63
# train loss: 0.155	train_acc: 0.899	train_f1: 0.885
# val loss:   0.219	val_acc:   0.877	val_f1:   0.863
#
# epoch: 64
# train loss: 0.155	train_acc: 0.898	train_f1: 0.885
# val loss:   0.220	val_acc:   0.877	val_f1:   0.863
#
# epoch: 65
# train loss: 0.155	train_acc: 0.898	train_f1: 0.885
# val loss:   0.219	val_acc:   0.878	val_f1:   0.864
#
# epoch: 66
# train loss: 0.155	train_acc: 0.899	train_f1: 0.885
# val loss:   0.220	val_acc:   0.877	val_f1:   0.863
#
# epoch: 67
# train loss: 0.154	train_acc: 0.899	train_f1: 0.886
# val loss:   0.220	val_acc:   0.876	val_f1:   0.863
#
# epoch: 68
# train loss: 0.154	train_acc: 0.899	train_f1: 0.886
# val loss:   0.221	val_acc:   0.878	val_f1:   0.864
#
# epoch: 69
# train loss: 0.154	train_acc: 0.899	train_f1: 0.885
# val loss:   0.220	val_acc:   0.876	val_f1:   0.863
#
# epoch: 70
# train loss: 0.154	train_acc: 0.899	train_f1: 0.886
# val loss:   0.220	val_acc:   0.877	val_f1:   0.863
#
# epoch: 71
# train loss: 0.154	train_acc: 0.899	train_f1: 0.886
# val loss:   0.220	val_acc:   0.877	val_f1:   0.863
#
# epoch: 72
# train loss: 0.154	train_acc: 0.900	train_f1: 0.886
# val loss:   0.221	val_acc:   0.877	val_f1:   0.863
#
# epoch: 73
# train loss: 0.153	train_acc: 0.900	train_f1: 0.886
# val loss:   0.221	val_acc:   0.876	val_f1:   0.863
#
# epoch: 74
# train loss: 0.153	train_acc: 0.899	train_f1: 0.886
# val loss:   0.221	val_acc:   0.877	val_f1:   0.863
#
# epoch: 75
# train loss: 0.153	train_acc: 0.900	train_f1: 0.886
# val loss:   0.221	val_acc:   0.877	val_f1:   0.863
#
# epoch: 76
# train loss: 0.153	train_acc: 0.900	train_f1: 0.886
# val loss:   0.222	val_acc:   0.877	val_f1:   0.863
#
# epoch: 77
# train loss: 0.153	train_acc: 0.900	train_f1: 0.886
# val loss:   0.222	val_acc:   0.877	val_f1:   0.863
#
# epoch: 78
# train loss: 0.153	train_acc: 0.900	train_f1: 0.886
# val loss:   0.222	val_acc:   0.877	val_f1:   0.863
#
# epoch: 79
# train loss: 0.153	train_acc: 0.900	train_f1: 0.886
# val loss:   0.222	val_acc:   0.877	val_f1:   0.863
#
# epoch: 80
# train loss: 0.152	train_acc: 0.900	train_f1: 0.886
# val loss:   0.223	val_acc:   0.878	val_f1:   0.864
#
# epoch: 81
# train loss: 0.152	train_acc: 0.900	train_f1: 0.886
# val loss:   0.222	val_acc:   0.877	val_f1:   0.863
#
# epoch: 82
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.222	val_acc:   0.877	val_f1:   0.863
#
# epoch: 83
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 84
# train loss: 0.152	train_acc: 0.900	train_f1: 0.886
# val loss:   0.223	val_acc:   0.876	val_f1:   0.863
#
# epoch: 85
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 86
# train loss: 0.152	train_acc: 0.900	train_f1: 0.886
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 87
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 88
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.876	val_f1:   0.863
#
# epoch: 89
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 90
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 91
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 92
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 93
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 94
# train loss: 0.152	train_acc: 0.900	train_f1: 0.887
# val loss:   0.223	val_acc:   0.877	val_f1:   0.863
#
# epoch: 95
# train loss: 0.151	train_acc: 0.901	train_f1: 0.887
# val loss:   0.224	val_acc:   0.877	val_f1:   0.863
#
# epoch: 96
# train loss: 0.151	train_acc: 0.900	train_f1: 0.887
# val loss:   0.224	val_acc:   0.877	val_f1:   0.863
#
# epoch: 97
# train loss: 0.151	train_acc: 0.900	train_f1: 0.887
# val loss:   0.224	val_acc:   0.877	val_f1:   0.863
#
# epoch: 98
# train loss: 0.151	train_acc: 0.901	train_f1: 0.887
# val loss:   0.224	val_acc:   0.877	val_f1:   0.863
#
# epoch: 99
# train loss: 0.151	train_acc: 0.901	train_f1: 0.887
# val loss:   0.224	val_acc:   0.877	val_f1:   0.863
#
# epoch: 100
# train loss: 0.151	train_acc: 0.901	train_f1: 0.887
# val loss:   0.224	val_acc:   0.877	val_f1:   0.863

# %%
model_weight = torch.load("gru_state.pth")
model.load_state_dict(model_weight)

label_preds, label_targets = [], [] 

with torch.no_grad():
    for i, data in tqdm(enumerate(val_dl), total=len(val_dl)):
        comments, labels = data
        label_outputs = model(comments)
        label_preds.extend(label_outputs.argmax(-1).cpu().numpy())
        label_targets.extend(labels.cpu().numpy())
    print(classification_report(label_targets, label_preds))
# Out:
#   0%|          | 0/307 [00:00<?, ?it/s]
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1958
#            1       0.00      0.00      0.00        26
#            2       0.00      0.00      0.00        46
#            3       0.00      0.00      0.00        26
#            4       0.00      0.00      0.00        28
#            5       0.00      0.00      0.00        47
#            6       0.86      0.89      0.88       604
#            7       0.84      0.91      0.88      2175
#
#     accuracy                           0.88      4910
#    macro avg       0.33      0.34      0.33      4910
# weighted avg       0.85      0.88      0.86      4910
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
