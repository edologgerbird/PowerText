# %%
import pandas as pd
import numpy as np
from collections import Counter
import logging
import string
import re
import os
from tqdm.notebook import tqdm
from random import randint, shuffle

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    ConfusionMatrixDisplay,
    accuracy_score,
    f1_score
)

import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

device = 'cuda' if torch.cuda.is_available() else 'cpu'
sns.set_theme()
logging.basicConfig(filename='training_log.log',
                    format='%(asctime)s - %(message)s', 
                    level=logging.INFO,
                    filemode='w')
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='training_log.log', mode='a')
formatter = logging.Formatter('%(asctime)s: %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)


class Transformer(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_layers, num_classes):
        super(Transformer, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model, nhead),
            num_layers
        )
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        x = self.embedding(x)
        x = self.transformer(x.transpose(0, 1))
        x = x.mean(dim=0)
        x = self.fc(x)
        return x

class Tokenizer:
    def __init__(self, text_list, max_vocab_size=20000, n=3):
        self.max_vocab_size = max_vocab_size
        self.oov_token = "<OOV>"
        self.n = n
        self.build_vocab(text_list)

    def build_vocab(self, text_list):
        all_text = " ".join(self.preprocess(text) for text in text_list)
        ngrams = [self.ngramify(word) for word in all_text.split()]
        ngrams_flat = [ngram for word_ngrams in ngrams for ngram in word_ngrams] 
        ngram_count = Counter(ngrams_flat)
        vocab = [self.oov_token] + sorted(ngram_count, key=ngram_count.get, reverse=True)
        vocab = vocab[:self.max_vocab_size]
        self.word_to_id = {word: i for i, word in enumerate(vocab)}
        self.id_to_word = {i: word for word, i in self.word_to_id.items()}
        self.vocab_size = len(self.word_to_id)

    def preprocess(self, text):
        return text.lower()

    def ngramify(self, word):
        return [word[i:i + self.n] for i in range(len(word) - self.n + 1)]

    def encode(self, text):
        text = self.preprocess(text)
        words = text.split()
        ids = []
        for word in words:
            ngrams = self.ngramify(word)
            word_ids = [self.word_to_id.get(ngram, self.word_to_id[self.oov_token]) for ngram in ngrams]
            ids.extend(word_ids)
        return ids

    def decode(self, ids):
        ngrams = [self.id_to_word.get(id, self.oov_token) for id in ids]
        return "".join(ngrams)

    def __len__(self):
        return self.vocab_size


device = 'cuda' if torch.cuda.is_available() else 'cpu'


def pad_sequences(sequences, max_length):
    padded_sequences = []
    for seq in sequences:
        if len(seq) > max_length:
            seq = seq[:max_length]
        padded_seq = seq + [0] * (max_length - len(seq))
        padded_sequences.append(padded_seq)
    return padded_sequences

class DS(Dataset):
    def __init__(self, data_path, tokenizer, max_token_length=512):
        super().__init__()
        self.max_token_length = max_token_length

        self.labels = [
            'hate',
            'sexual',
            'impersonation',
            'illegal',
            'advertisement',
            'ai',
            'neutral'
        ]

        self.data = pd.read_csv(data_path)
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.loc[idx, :]


        comment = row['body']
        comment = comment.split()

        if len(comment) > self.max_token_length:
            comment = comment[:self.max_token_length]
        comment = ' '.join(comment)
        comment = comment.replace("\\", "")

        emotion = row['label']
        emotion = self.labels.index(emotion)

        return f"{comment}", emotion

    def choose(self):
        return self[randint(0, len(self)-1)]

    def get_tokenizer_size(self):
        return len(self.tokenizer)

    def decode(self, input_id):
        return self.tokenizer.decode(input_id)

    def collate_fn(self, data):
        comments, emotions = zip(*data)
        comments = [self.tokenizer.encode(comment) for comment in comments]
        comments = pad_sequences(comments, self.max_token_length)
        comments = torch.tensor(comments, dtype=torch.long, device=device)
        emotions = torch.tensor(emotions).long().to(device)
        return comments, emotions

# %%
val_path = 'https://drive.google.com/uc?export=download&id=1Y8MxkZTCrWm3em0gUmcTJQDLXayi68oO'
train_path = 'https://drive.google.com/uc?export=download&id=1Y4VLspBCBjuIJRnwPKUuV5hqucyuQUKm'
train_df_orig = pd.read_csv(train_path)
val_df_orig = pd.read_csv(val_path)

train_df = train_df_orig.copy()
val_df = val_df_orig.copy()
print(f'Size of training data: {len(train_df)}')
print(f'Size of validation data: {len(val_df)}')

tokenizer = Tokenizer(train_df["body"].tolist())
batch_size = 16

train_ds = DS(train_path, tokenizer)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True, collate_fn=train_ds.collate_fn)
val_ds = DS(val_path, tokenizer)
val_dl = DataLoader(val_ds, batch_size=batch_size, collate_fn=val_ds.collate_fn)
# Out:
# Size of training data: 37082
# Size of validation data: 4121

# %%
model = Transformer(vocab_size=train_ds.get_tokenizer_size(), d_model=128, nhead=4, num_layers=4, num_classes=len(train_ds.labels)).to(device)

# %%
# from alson's training code

def compute_metrics(targets, preds):
    targets = targets.cpu().detach()
    preds = preds.cpu().detach()
    acc = accuracy_score(targets, preds)
    f1 = f1_score(targets, preds, average='weighted')
    return {'acc': acc, 'f1': f1, 'preds': preds, 'targets':targets}

def focal_loss(gamma=2):
    def compute_loss(preds, targets):
        ce_loss = F.cross_entropy(preds, targets, reduction='none')
        pt = torch.exp(-ce_loss) 
        return ((1-pt)**gamma * ce_loss).mean()
    return compute_loss

def train(data, model, optimizer, label_loss_fn, ft_lambda=1e-4):
    model.train()
    comments, labels = data
    label_outputs = model(comments)
    label_loss = label_loss_fn(label_outputs, labels)
    loss = label_loss
    model.zero_grad()
    loss.backward()
    optimizer.step()

    label_preds = label_outputs.argmax(-1)
    label_metrics = compute_metrics(labels, label_preds)
    return loss, label_metrics

@torch.no_grad()
def validate(data, model, label_loss_fnn):
    model.eval()
    comments, labels = data
    label_outputs = model(comments)
    label_loss = label_loss_fnn(label_outputs, labels)
    loss = label_loss

    label_preds = label_outputs.argmax(-1)
    label_metrics = compute_metrics(labels, label_preds)
    return loss, label_metrics

n_epoch = 100
loss_fn = focal_loss()
optimizer = optim.AdamW(model.parameters(), lr=2e-5, weight_decay=0.01)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)

mem = {
    'train_loss': [],
    'train_acc': [],
    'train_f1': [],
    'val_loss': [],
    'val_acc': [],
    'val_f1': []
}

cur_best_f1 = 0

for epoch in tqdm(range(n_epoch), desc='Training'):

    n_batch = len(train_dl)
    train_losses = []
    train_accs = []
    train_f1s = []

    for i, data in enumerate(train_dl):
        train_loss, train_metrics = train(data, model, optimizer, loss_fn, loss_fn)
        pos = epoch + ((i+1)/n_batch)
        train_losses.append(train_loss.cpu().detach())
        train_accs.append(train_metrics['acc'])
        train_f1s.append(train_metrics['f1'])
        log = f"epoch: {pos:.3f}\ttrain loss: {train_loss:.3f}\ttrain_acc: {train_metrics['acc']:.3f}\ttrain_f1: {train_metrics['f1']:.3f}"
        print('\r', log, end='')
    
    mem['train_loss'].append(np.mean(train_losses))
    mem['train_acc'].append(np.mean(train_accs))
    mem['train_f1'].append(np.mean(train_f1s))

    n_batch = len(val_dl)
    val_losses = []
    val_accs = []
    val_f1s = []

    for i, data in enumerate(val_dl):
        val_loss, val_metrics = validate(data, model, loss_fn)
        pos = epoch + ((i+1)/n_batch)
        val_losses.append(val_loss.cpu().detach())
        val_accs.append(val_metrics['acc'])
        val_f1s.append(val_metrics['f1'])
        log = f"epoch: {pos:.3f}\tval loss: {val_loss:.3f}\tval_acc: {val_metrics['acc']:.3f}\tval_f1: {val_metrics['f1']:.3f}"
        print('\r', log, end='')
    
    print('\r', end='')
    mem['val_loss'].append(np.mean(val_losses))
    mem['val_acc'].append(np.mean(val_accs))
    mem['val_f1'].append(np.mean(val_f1s))

    log = f"epoch: {epoch+1}\ntrain loss: {mem['train_loss'][-1]:.3f}\ttrain_acc: {mem['train_acc'][-1]:.3f}\ttrain_f1: {mem['train_f1'][-1]:.3f}"
    log = log + f"\nval loss:   {mem['val_loss'][-1]:.3f}\tval_acc:   {mem['val_acc'][-1]:.3f}\tval_f1:   {mem['val_f1'][-1]:.3f}\n"
    logger.info(log)
    print(log)
    scheduler.step()    

    if mem['val_f1'][-1] > cur_best_f1:
        torch.save(model.state_dict(), f"transformer_weights.pth")
        cur_best_f1 = mem['val_f1'][-1]
# Out:
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# epoch: 1
# train loss: 0.202	train_acc: 0.791	train_f1: 0.770
# val loss:   0.141	val_acc:   0.881	val_f1:   0.869
#
# epoch: 2
# train loss: 0.123	train_acc: 0.886	train_f1: 0.874
# val loss:   0.113	val_acc:   0.895	val_f1:   0.883
#
# epoch: 3
# train loss: 0.106	train_acc: 0.892	train_f1: 0.882
# val loss:   0.106	val_acc:   0.894	val_f1:   0.889
#
# epoch: 4
# train loss: 0.095	train_acc: 0.898	train_f1: 0.891
# val loss:   0.107	val_acc:   0.885	val_f1:   0.887
#
# epoch: 5
# train loss: 0.087	train_acc: 0.904	train_f1: 0.898
# val loss:   0.102	val_acc:   0.885	val_f1:   0.890
#
# epoch: 6
# train loss: 0.082	train_acc: 0.908	train_f1: 0.903
# val loss:   0.101	val_acc:   0.884	val_f1:   0.890
#
# epoch: 7
# train loss: 0.077	train_acc: 0.911	train_f1: 0.907
# val loss:   0.086	val_acc:   0.908	val_f1:   0.904
#
# epoch: 8
# train loss: 0.073	train_acc: 0.912	train_f1: 0.909
# val loss:   0.086	val_acc:   0.908	val_f1:   0.905
#
# epoch: 9
# train loss: 0.070	train_acc: 0.915	train_f1: 0.912
# val loss:   0.085	val_acc:   0.907	val_f1:   0.907
#
# epoch: 10
# train loss: 0.067	train_acc: 0.915	train_f1: 0.913
# val loss:   0.081	val_acc:   0.913	val_f1:   0.910
#
# epoch: 11
# train loss: 0.065	train_acc: 0.919	train_f1: 0.917
# val loss:   0.085	val_acc:   0.906	val_f1:   0.908
#
# epoch: 12
# train loss: 0.062	train_acc: 0.921	train_f1: 0.920
# val loss:   0.084	val_acc:   0.912	val_f1:   0.911
#
# epoch: 13
# train loss: 0.060	train_acc: 0.923	train_f1: 0.921
# val loss:   0.083	val_acc:   0.911	val_f1:   0.909
#
# epoch: 14
# train loss: 0.058	train_acc: 0.924	train_f1: 0.923
# val loss:   0.080	val_acc:   0.915	val_f1:   0.912
#
# epoch: 15
# train loss: 0.056	train_acc: 0.924	train_f1: 0.923
# val loss:   0.084	val_acc:   0.908	val_f1:   0.911
#
# epoch: 16
# train loss: 0.055	train_acc: 0.927	train_f1: 0.926
# val loss:   0.082	val_acc:   0.912	val_f1:   0.911
#
# epoch: 17
# train loss: 0.053	train_acc: 0.928	train_f1: 0.927
# val loss:   0.093	val_acc:   0.917	val_f1:   0.912
#
# epoch: 18
# train loss: 0.051	train_acc: 0.930	train_f1: 0.929
# val loss:   0.084	val_acc:   0.917	val_f1:   0.915
#
# epoch: 19
# train loss: 0.050	train_acc: 0.932	train_f1: 0.931
# val loss:   0.091	val_acc:   0.912	val_f1:   0.913
#
# epoch: 20
# train loss: 0.049	train_acc: 0.932	train_f1: 0.932
# val loss:   0.085	val_acc:   0.915	val_f1:   0.913
#
# epoch: 21
# train loss: 0.048	train_acc: 0.934	train_f1: 0.933
# val loss:   0.089	val_acc:   0.914	val_f1:   0.911
#
# epoch: 22
# train loss: 0.046	train_acc: 0.935	train_f1: 0.934
# val loss:   0.090	val_acc:   0.916	val_f1:   0.915
#
# epoch: 23
# train loss: 0.046	train_acc: 0.936	train_f1: 0.935
# val loss:   0.097	val_acc:   0.909	val_f1:   0.907
#
# epoch: 24
# train loss: 0.044	train_acc: 0.938	train_f1: 0.938
# val loss:   0.094	val_acc:   0.914	val_f1:   0.914
#
# epoch: 25
# train loss: 0.043	train_acc: 0.939	train_f1: 0.938
# val loss:   0.095	val_acc:   0.915	val_f1:   0.914
#
# epoch: 26
# train loss: 0.042	train_acc: 0.939	train_f1: 0.939
# val loss:   0.098	val_acc:   0.906	val_f1:   0.908
#
# epoch: 27
# train loss: 0.041	train_acc: 0.943	train_f1: 0.942
# val loss:   0.097	val_acc:   0.912	val_f1:   0.911
#
# epoch: 28
# train loss: 0.041	train_acc: 0.942	train_f1: 0.942
# val loss:   0.100	val_acc:   0.914	val_f1:   0.912
#
# epoch: 29
# train loss: 0.040	train_acc: 0.943	train_f1: 0.942
# val loss:   0.101	val_acc:   0.912	val_f1:   0.913
#
# epoch: 30
# train loss: 0.038	train_acc: 0.944	train_f1: 0.944
# val loss:   0.103	val_acc:   0.914	val_f1:   0.913
#
# epoch: 31
# train loss: 0.038	train_acc: 0.945	train_f1: 0.945
# val loss:   0.105	val_acc:   0.916	val_f1:   0.915
#
# epoch: 32
# train loss: 0.038	train_acc: 0.946	train_f1: 0.946
# val loss:   0.107	val_acc:   0.914	val_f1:   0.914
#
# epoch: 33
# train loss: 0.037	train_acc: 0.948	train_f1: 0.947
# val loss:   0.111	val_acc:   0.908	val_f1:   0.909
#
# epoch: 34
# train loss: 0.036	train_acc: 0.949	train_f1: 0.949
# val loss:   0.112	val_acc:   0.913	val_f1:   0.913
#
# epoch: 35
# train loss: 0.035	train_acc: 0.950	train_f1: 0.950
# val loss:   0.112	val_acc:   0.909	val_f1:   0.910
#
# epoch: 36
# train loss: 0.035	train_acc: 0.950	train_f1: 0.950
# val loss:   0.113	val_acc:   0.910	val_f1:   0.910
#
# epoch: 37
# train loss: 0.034	train_acc: 0.950	train_f1: 0.950
# val loss:   0.116	val_acc:   0.912	val_f1:   0.911
#
# epoch: 38
# train loss: 0.034	train_acc: 0.952	train_f1: 0.951
# val loss:   0.117	val_acc:   0.912	val_f1:   0.911
#
# epoch: 39
# train loss: 0.033	train_acc: 0.951	train_f1: 0.951
# val loss:   0.119	val_acc:   0.910	val_f1:   0.910
#
# epoch: 40
# train loss: 0.033	train_acc: 0.952	train_f1: 0.952
# val loss:   0.121	val_acc:   0.909	val_f1:   0.908
#
# epoch: 41
# train loss: 0.032	train_acc: 0.953	train_f1: 0.953
# val loss:   0.121	val_acc:   0.911	val_f1:   0.910
#
# epoch: 42
# train loss: 0.032	train_acc: 0.954	train_f1: 0.954
# val loss:   0.122	val_acc:   0.908	val_f1:   0.908
#
# epoch: 43
# train loss: 0.031	train_acc: 0.955	train_f1: 0.955
# val loss:   0.127	val_acc:   0.908	val_f1:   0.908
#
# epoch: 44
# train loss: 0.031	train_acc: 0.956	train_f1: 0.955
# val loss:   0.127	val_acc:   0.909	val_f1:   0.909
#
# epoch: 45
# train loss: 0.030	train_acc: 0.955	train_f1: 0.955
# val loss:   0.125	val_acc:   0.906	val_f1:   0.905
#
# epoch: 46
# train loss: 0.030	train_acc: 0.956	train_f1: 0.956
# val loss:   0.132	val_acc:   0.906	val_f1:   0.907
#
# epoch: 47
# train loss: 0.030	train_acc: 0.956	train_f1: 0.955
# val loss:   0.133	val_acc:   0.912	val_f1:   0.912
#
# epoch: 48
# train loss: 0.029	train_acc: 0.958	train_f1: 0.957
# val loss:   0.131	val_acc:   0.906	val_f1:   0.906
#
# epoch: 49
# train loss: 0.029	train_acc: 0.958	train_f1: 0.957
# val loss:   0.132	val_acc:   0.911	val_f1:   0.910
#
# epoch: 50
# train loss: 0.029	train_acc: 0.959	train_f1: 0.958
# val loss:   0.135	val_acc:   0.907	val_f1:   0.907
#
# epoch: 51
# train loss: 0.028	train_acc: 0.959	train_f1: 0.959
# val loss:   0.136	val_acc:   0.909	val_f1:   0.908
#
# epoch: 52
# train loss: 0.028	train_acc: 0.959	train_f1: 0.958
# val loss:   0.138	val_acc:   0.905	val_f1:   0.906
#
# epoch: 53
# train loss: 0.028	train_acc: 0.959	train_f1: 0.959
# val loss:   0.136	val_acc:   0.907	val_f1:   0.907
#
# epoch: 54
# train loss: 0.028	train_acc: 0.960	train_f1: 0.960
# val loss:   0.136	val_acc:   0.908	val_f1:   0.907
#
# epoch: 55
# train loss: 0.027	train_acc: 0.961	train_f1: 0.961
# val loss:   0.139	val_acc:   0.910	val_f1:   0.909
#
# epoch: 56
# train loss: 0.027	train_acc: 0.961	train_f1: 0.960
# val loss:   0.136	val_acc:   0.907	val_f1:   0.907
#
# epoch: 57
# train loss: 0.027	train_acc: 0.961	train_f1: 0.961
# val loss:   0.139	val_acc:   0.905	val_f1:   0.904
#
# epoch: 58
# train loss: 0.026	train_acc: 0.961	train_f1: 0.961
# val loss:   0.140	val_acc:   0.905	val_f1:   0.904
#
# epoch: 59
# train loss: 0.027	train_acc: 0.962	train_f1: 0.962
# val loss:   0.142	val_acc:   0.907	val_f1:   0.907
#
# epoch: 60
# train loss: 0.026	train_acc: 0.962	train_f1: 0.962
# val loss:   0.141	val_acc:   0.905	val_f1:   0.904
#
# epoch: 61
# train loss: 0.026	train_acc: 0.962	train_f1: 0.962
# val loss:   0.144	val_acc:   0.906	val_f1:   0.905
#
# epoch: 62
# train loss: 0.026	train_acc: 0.963	train_f1: 0.963
# val loss:   0.143	val_acc:   0.907	val_f1:   0.906
#
# epoch: 63
# train loss: 0.026	train_acc: 0.963	train_f1: 0.963
# val loss:   0.145	val_acc:   0.907	val_f1:   0.907
#
# epoch: 64
# train loss: 0.026	train_acc: 0.963	train_f1: 0.963
# val loss:   0.142	val_acc:   0.905	val_f1:   0.904
#
# epoch: 65
# train loss: 0.025	train_acc: 0.964	train_f1: 0.963
# val loss:   0.146	val_acc:   0.905	val_f1:   0.905
#
# epoch: 66
# train loss: 0.026	train_acc: 0.963	train_f1: 0.962
# val loss:   0.145	val_acc:   0.904	val_f1:   0.904
#
# epoch: 67
# train loss: 0.025	train_acc: 0.963	train_f1: 0.963
# val loss:   0.145	val_acc:   0.905	val_f1:   0.904
#
# epoch: 68
# train loss: 0.025	train_acc: 0.965	train_f1: 0.964
# val loss:   0.146	val_acc:   0.904	val_f1:   0.903
#
# epoch: 69
# train loss: 0.025	train_acc: 0.964	train_f1: 0.963
# val loss:   0.147	val_acc:   0.905	val_f1:   0.905
#
# epoch: 70
# train loss: 0.025	train_acc: 0.964	train_f1: 0.964
# val loss:   0.148	val_acc:   0.905	val_f1:   0.905
#
# epoch: 71
# train loss: 0.025	train_acc: 0.965	train_f1: 0.964
# val loss:   0.148	val_acc:   0.902	val_f1:   0.901
#
# epoch: 72
# train loss: 0.025	train_acc: 0.964	train_f1: 0.964
# val loss:   0.149	val_acc:   0.906	val_f1:   0.905
#
# epoch: 73
# train loss: 0.024	train_acc: 0.964	train_f1: 0.964
# val loss:   0.148	val_acc:   0.904	val_f1:   0.904
#
# epoch: 74
# train loss: 0.024	train_acc: 0.965	train_f1: 0.964
# val loss:   0.149	val_acc:   0.906	val_f1:   0.905
#
# epoch: 75
# train loss: 0.024	train_acc: 0.964	train_f1: 0.964
# val loss:   0.149	val_acc:   0.904	val_f1:   0.903
#
# epoch: 76
# train loss: 0.024	train_acc: 0.965	train_f1: 0.965
# val loss:   0.151	val_acc:   0.906	val_f1:   0.906
#
# epoch: 77
# train loss: 0.024	train_acc: 0.964	train_f1: 0.964
# val loss:   0.150	val_acc:   0.905	val_f1:   0.905
#
# epoch: 78
# train loss: 0.024	train_acc: 0.965	train_f1: 0.965
# val loss:   0.152	val_acc:   0.906	val_f1:   0.905
#
# epoch: 79
# train loss: 0.024	train_acc: 0.966	train_f1: 0.965
# val loss:   0.151	val_acc:   0.905	val_f1:   0.904
#
# epoch: 80
# train loss: 0.024	train_acc: 0.965	train_f1: 0.965
# val loss:   0.152	val_acc:   0.904	val_f1:   0.903
#
# epoch: 81
# train loss: 0.024	train_acc: 0.966	train_f1: 0.965
# val loss:   0.152	val_acc:   0.905	val_f1:   0.904
#
# epoch: 82
# train loss: 0.024	train_acc: 0.966	train_f1: 0.966
# val loss:   0.153	val_acc:   0.904	val_f1:   0.904
#
# epoch: 83
# train loss: 0.024	train_acc: 0.966	train_f1: 0.966
# val loss:   0.152	val_acc:   0.905	val_f1:   0.905
#
# epoch: 84
# train loss: 0.024	train_acc: 0.966	train_f1: 0.966
# val loss:   0.152	val_acc:   0.904	val_f1:   0.903
#
# epoch: 85
# train loss: 0.024	train_acc: 0.966	train_f1: 0.965
# val loss:   0.154	val_acc:   0.905	val_f1:   0.904
#
# epoch: 86
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.153	val_acc:   0.903	val_f1:   0.902
#
# epoch: 87
# train loss: 0.024	train_acc: 0.966	train_f1: 0.966
# val loss:   0.153	val_acc:   0.904	val_f1:   0.903
#
# epoch: 88
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.153	val_acc:   0.902	val_f1:   0.901
#
# epoch: 89
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.153	val_acc:   0.903	val_f1:   0.902
#
# epoch: 90
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.154	val_acc:   0.903	val_f1:   0.902
#
# epoch: 91
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.155	val_acc:   0.902	val_f1:   0.902
#
# epoch: 92
# train loss: 0.023	train_acc: 0.967	train_f1: 0.967
# val loss:   0.155	val_acc:   0.905	val_f1:   0.904
#
# epoch: 93
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.155	val_acc:   0.905	val_f1:   0.904
#
# epoch: 94
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.155	val_acc:   0.904	val_f1:   0.904
#
# epoch: 95
# train loss: 0.023	train_acc: 0.967	train_f1: 0.967
# val loss:   0.156	val_acc:   0.904	val_f1:   0.904
#
# epoch: 96
# train loss: 0.023	train_acc: 0.967	train_f1: 0.967
# val loss:   0.156	val_acc:   0.904	val_f1:   0.904
#
# epoch: 97
# train loss: 0.023	train_acc: 0.967	train_f1: 0.967
# val loss:   0.156	val_acc:   0.905	val_f1:   0.905
#
# epoch: 98
# train loss: 0.023	train_acc: 0.967	train_f1: 0.967
# val loss:   0.155	val_acc:   0.904	val_f1:   0.903
#
# epoch: 99
# train loss: 0.023	train_acc: 0.967	train_f1: 0.967
# val loss:   0.156	val_acc:   0.905	val_f1:   0.904
#
# epoch: 100
# train loss: 0.023	train_acc: 0.966	train_f1: 0.966
# val loss:   0.156	val_acc:   0.904	val_f1:   0.904

# %%
model_weight = torch.load("transformer_weights.pth")
model.load_state_dict(model_weight)

label_preds, label_targets = [], []

with torch.no_grad():
    for i, data in tqdm(enumerate(val_dl), total=len(val_dl)):
        comments, labels = data
        label_outputs = model(comments)
        label_preds.extend(label_outputs.argmax(-1).cpu().numpy())
        label_targets.extend(labels.cpu().numpy())
    print(classification_report(label_targets, label_preds))
# Out:
#   0%|          | 0/258 [00:00<?, ?it/s]
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      1930
#            1       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         3
#            5       0.66      0.69      0.68       120
#            6       0.92      0.91      0.92      2066
#
#     accuracy                           0.92      4121
#    macro avg       0.42      0.42      0.42      4121
# weighted avg       0.91      0.92      0.92      4121
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
